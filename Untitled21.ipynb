# %% [markdown]
# <a href="https://colab.research.google.com/github/swarna34s/Data-visualizationtraining-ITPR/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to open file for read operation
filev =open("firstfile.txt","r")
#to check file is open or not
if(filev):
#to read data from file
  data= filev.read()
  print(data)
  print("----------")
  print("no.of characters:",len(data))
  #closing file
  filev.close()
else:
  print("unable to open the file")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_917/2869095586.py in <cell line: 0>()
#       1 # to open file for read operation
# ----> 2 filev =open("firstfile.txt","r")
#       3 #to check file is open or not
#       4 if(filev):
#       5 #to read data from file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'firstfile.txt'
