# %% [markdown]
# <a href="https://colab.research.google.com/github/swarna34s/Data-visualizationtraining-ITPR/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#maim program
Principal=float(input("enter principal (in rs):))
Rate=float(input("enter rate of interest (iny):"))
Time=int(input("enter time( in year):"))
Print("simple interest:rs", calculator:(principal rate time)
