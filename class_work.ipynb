# %% [markdown]
# <a href="https://colab.research.google.com/github/swarna34s/Data-visualizationtraining-ITPR/blob/main/class_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# array creation in numpy
array3= np.zeros(3,5)
print(array3)

# %%
array4 = np.zeros((4,5),dtype='int')
print (array4)

# %%
import numpy as np

arr = np.zeros((3, 6, 2), dtype=int)
print(arr)

# %%
# ones array
array5 = np.ones((4,3))
print(array5)

# %%
import numpy as np
arr= np.ones(3,2,5,1),dtype=int)
print(arr)

# %%
import numpy as np

n = int(input("Enter a number: "))

even_factors = [i for i in range(1, n+1) if n % i == 0 and i % 2 == 0]

arr = np.array(even_factors)

print("Even factors array:", arr)
