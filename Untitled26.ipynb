# %% [markdown]
# <a href="https://colab.research.google.com/github/swarna34s/Data-visualizationtraining-ITPR/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to copy content from one file to another

# Open source file in read mode
source = open("source.txt", "r")

# Open destination file in write mode
destination = open("destination.txt", "w")

# Read content from source file
content = source.read()

# Write content to destination file
destination.write(content)

# Close both files
source.close()
destination.close()

print("File copied successfully!")
