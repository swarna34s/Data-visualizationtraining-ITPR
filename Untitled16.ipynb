# %% [markdown]
# <a href="https://colab.research.google.com/github/swarna34s/Data-visualizationtraining-ITPR/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# grade assignment
marks= int(input("enter marks:"))
if marks>=90:
  print("A")
elif marks>=75:
  print("B")
elif marks>=60:
  print("c")
elif marks>=50:
  print("D")
else:
  print("f")
