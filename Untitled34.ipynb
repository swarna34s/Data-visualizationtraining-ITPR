# %% [markdown]
# <a href="https://colab.research.google.com/github/swarna34s/Data-visualizationtraining-ITPR/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find longest line in a file

with open("data.txt", "r") as file:
    lines = file.readlines()

longest_line = max(lines, key=len)

print("Longest Line:", longest_line.strip())
print("Length:", len(longest_line))
