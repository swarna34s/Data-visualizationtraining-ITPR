# %% [markdown]
# <a href="https://colab.research.google.com/github/swarna34s/Data-visualizationtraining-ITPR/blob/main/lab_work_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#first array
array1=np.array([10,30,40,50])
#second array
array2=np.array([90,70,30,50])
#-----------------
print("first array:")
print(array1)
print("---------------------")
print("second array:")
print(array2)
#---------------------")
#addition of array
#use array3=np.add(array1,array2)
#----------------------
array3=np.add(array1,array2)
print("sum of both array:")
print(array3)
print("-----------------------")
#subtract of array
#use array4=np.subtract (array1,array2)
#-------------------------
array4=np.subtract (array1,array2)
print("difference of both array:")
print(array4)
