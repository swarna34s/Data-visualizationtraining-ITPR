# %% [markdown]
# <a href="https://colab.research.google.com/github/swarna34s/Data-visualizationtraining-ITPR/blob/main/Untitled37.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Display last N lines of a file

n = int(input("Enter number of lines: "))

with open("data.txt", "r") as file:
    lines = file.readlines()

for line in lines[-n:]:
    print(line.strip())
